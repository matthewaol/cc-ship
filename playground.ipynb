# %%
import pandas as pd 
import numpy as np

# %%
ships_df = pd.read_csv("stem_center_internships.csv")

# %%
ships_df
# Out:
#                                Internship Opportunity  \
# 0              Stanford Linear Accelerator Laboratory
# 1   Community College Internships (CCI) - Summer S...
# 2                            University of Washington
# 3                REU-Blinks Summer Internship Program
# 4   Astrophysics and Planetary Science Research at...
# ..                                                ...
# 63                          National Cancer Institute
# 64           National Science Foundation - REU Finder
# 65                 STEM Jobs - Internship search tool
# 66                                  Energize Colleges
# 67    S-SMART Summer Research Internship Program 2023
#
#                  Discipline  \
# 0                  Multiple
# 1                  All STEM
# 2        Neural Engineering
# 3       Biology and Ecology
# 4              Astrophysics
# ..                      ...
# 63                      NaN
# 64                 Multiple
# 65                 Multiple
# ...

# %%
def find_major(df, major):
    if "computer" in major:
        return df[df['Discipline'].str.contains('Computer|Coding|Multiple',case=False, na=False)]
    if "engineering" in major:
        return df[df['Discipline'].str.contains('Engineering|Multiple',case=False, na=False)]

# %%
major = str(input("What is your major?"))
find_major(ships_df, major)
# Out:
# What is your major? computer
#                                Internship Opportunity  \
# 0              Stanford Linear Accelerator Laboratory
# 6   Problem-based Initiatives for Powerful Engagem...
# 7            Monterey Bay Aquarium Research Institute
# 8                    City and County of San Francisco
# 10                              The New Technologists
# 11  California Academy of Sciences- Summer Systema...
# 12                    Summer Research at Georgia Tech
# 16  Ocean research @ Bigelow Laboratory's Summer R...
# 19     Sustainable Materials Research @ UC Santa Cruz
# 21  HACU National Internship Program (HNIP) @ Vari...
# 22  Merced Nanomaterials Center for Energy and Sen...
# 23                                 ASSURE REU Program
# 24  Earthquake Information Technology @ Univ of So...
# 27  Complexity Across Disciplines - Math REU @ Boi...
# 28                          IQ Bio REU in Puerto Rico
# 29           Women Coders Open Source Software in May
# ...
